# %%
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
gen_params = {'canvas_dimension' : {'figsize':(5,5)},
              'x_title_dimension': {'size':12},
              'y_title_dimension': {'size':12},
              'z_title_dimension': {'size':12},
              'horizontal_line'  : {'color':'black', 'lw':0.5, 'ls':'--', 'zorder':1}}

plot= {'S0' : {'color' : '#00008B', 'lw' : 1, 'zorder' : 0, 'alpha' : 0.8},
       'S1' : {'color' : '#008000', 'lw' : 1, 'zorder' : 0, 'alpha' : 0.8},
       'S2' : {'color' : '#A52A2A', 'lw' : 1, 'zorder' : 0, 'alpha' : 0.8}}

scat= {'S0' : {'color' : '#00008B', 'marker' : 'o' ,'zorder' : 4, 'alpha' : 1},
       'S1' : {'color' : '#008000', 'marker' : 'o' ,'zorder' : 4, 'alpha' : 1},
       'S2' : {'color' : '#A52A2A', 'marker' : 'o' ,'zorder' : 4, 'alpha' : 1}}

# %%
path = '/home/leonardo/Desktop'
csv_1 ='/home/leonardo/Desktop/Pipelines/DISPLACEMENT_PIPELINE/INTERPOLATE_BETWEEN_GEOMETRIES/arch7/cross-meci-gvec/results-xms.csv'
#csv_1 = '/home/leonardo/Desktop/Pipelines/DISPLACEMENT_PIPELINE/INTERPOLATE_BETWEEN_GEOMETRIES/arch3/results/fc-results.csv'
#csv_2 = '/home/leonardo/Desktop/Pipelines/DISPLACEMENT_PIPELINE/INTERPOLATE_BETWEEN_GEOMETRIES/arch3/results/pla-results.csv'
#csv_3 = '/home/leonardo/Desktop/Pipelines/DISPLACEMENT_PIPELINE/INTERPOLATE_BETWEEN_GEOMETRIES/arch3/results/tict-results.csv'
#csv_1 = '/home/leonardo/Desktop/Pipelines/DISPLACEMENT_PIPELINE/INTERPOLATE_BETWEEN_GEOMETRIES/arch7/cross-fc/results-xms-caspt2/results_xms.csv'
#csv_2 = '/home/leonardo/Desktop/Pipelines/DISPLACEMENT_PIPELINE/INTERPOLATE_BETWEEN_GEOMETRIES/arch7/cross-pla/results-xms-caspt2/results_pla_xms.csv'
#csv_3 = '/home/leonardo/Desktop/Pipelines/DISPLACEMENT_PIPELINE/INTERPOLATE_BETWEEN_GEOMETRIES/arch7/results-tict/sa3-xms-caspt2-ano-l/mp2-vector/results_tict_mp2_xms.csv'
#csv_4 = '/home/leonardo/Desktop/Pipelines/DISPLACEMENT_PIPELINE/INTERPOLATE_BETWEEN_GEOMETRIES/arch7/cross-fc_pla/results_xms_caspt2/results_xms.csv'
#csv_4 = '/home/leonardo/Desktop/Pipelines/DISPLACEMENT_PIPELINE/INTERPOLATE_BETWEEN_GEOMETRIES/arch7/cross-tict/meci-tict_displaced/results/sa3-xms-caspt2/results_xms_meci-tict.csv'
#csv_4 = '/home/leonardo/Desktop/Pipelines/DISPLACEMENT_PIPELINE/INTERPOLATE_BETWEEN_GEOMETRIES/arch7/cross-tict/meci-tict_displaced/results/remake_sa3-xms-caspt2/results_sa3_xms.csv'
df_1 = pd.read_csv(csv_1)
#df_2 = pd.read_csv(csv_2)
#df_3 = pd.read_csv(csv_3)
#df_4 = pd.read_csv(csv_4)
png_name_1 = (csv_1.split('/')[-1][:-4])
#png_name_2 = (csv_2.split('/')[-1][:-4])
#png_name_3 = (csv_3.split('/')[-1][:-4])
#png_name_4 = (csv_4.split('/')[-1][:-4])

# %%
df_1 = df_1.sort_values('full-BLA')
#df_2 = df_2.sort_values('full-BLA')
#df_3 = df_3.sort_values('full-BLA')
#df_4 = df_4.sort_values('full-BLA')

# %%
df_1
# Out:
#     Reactive TORS  full-BLA  bion-BLA   psb-BLA  S0 CASSCF Energy  \
# 20    -101.011732 -0.027516  0.048778 -0.248733       -869.071519
# 19    -101.061570 -0.022724  0.044181 -0.207069       -869.083526
# 18    -101.113644 -0.017937  0.039582 -0.165397       -869.093360
# 17    -101.168228 -0.013156  0.034981 -0.123722       -869.101104
# 16    -101.225245 -0.008381  0.030377 -0.082042       -869.107169
# 15    -101.284454 -0.003613  0.025770 -0.040365       -869.112728
# 14    -101.346070  0.001148  0.021162  0.001309       -869.117722
# 13    -101.409968  0.005901  0.016551  0.042975       -869.121120
# 12    -101.475954  0.010645  0.011938  0.084628       -869.122847
# 11    -101.544309  0.015379  0.007323  0.126268       -869.123128
# 10    -101.614597  0.020104  0.002705  0.167890       -869.121689
# 0     -101.687079  0.024818 -0.001915  0.209489       -869.118414
# 1     -101.761728  0.029520 -0.006537  0.251064       -869.113176
# ...

# %%
def cross_section_graphics(df, png_name):
    fig, ax = plt.subplots()#**gen_params['canvas_dimension'])
    
    #ax.scatter(df['full-BLA'], df['Scaled S0 CASSCF Energy'],**scat['S0'])
    #ax.scatter(df['full-BLA'], df['Scaled S1 CASSCF Energy'],**scat['S0'])
    #ax.plot(df['full-BLA'], df['Scaled S0 CASSCF Energy'],'o-', **scat['S0'],  label='SA-CASSCF/6-31G*')
    #ax.plot(df['full-BLA'], df['Scaled S1 CASSCF Energy'],**scat['S0'])
    ax.scatter(df['full-BLA'], df['Scaled S0 XMS-CASPT2 Energy'],**scat['S1'], )
    ax.scatter(df['full-BLA'], df['Scaled S1 XMS-CASPT2 Energy'],**scat['S1'])
    ax.scatter(df['full-BLA'], df['Scaled S2 XMS-CASPT2 Energy'],**scat['S1'])
    ax.plot(df['full-BLA'], df['Scaled S0 XMS-CASPT2 Energy'],'o-',**scat['S1'], label='XMS-CASPT2/ANO-L-pVDZ')
    ax.plot(df['full-BLA'], df['Scaled S1 XMS-CASPT2 Energy'],**scat['S1'], label='_no_legend_')
    ax.plot(df['full-BLA'], df['Scaled S2 XMS-CASPT2 Energy'],**scat['S1'], label='_no_legend_')
    
    #ax.scatter(df['Reactive TORS'], df['Scaled S0 CASSCF Energy'],**scat['S0'])
    #ax.scatter(df['Reactive TORS'], df['Scaled S1 CASSCF Energy'],**scat['S0'])
    #ax.plot(df['Reactive TORS'], df['Scaled S0 CASSCF Energy'],'o-', **scat['S0'],  label='SA-CASSCF/6-31G*')
    #ax.plot(df['Reactive TORS'], df['Scaled S1 CASSCF Energy'],**scat['S0'])
    #ax.scatter(df['Reactive TORS'], df['Scaled S0 XMS-CASPT2 Energy'],**scat['S1'], )
    #ax.scatter(df['Reactive TORS'], df['Scaled S1 XMS-CASPT2 Energy'],**scat['S1'])
    #ax.scatter(df['Reactive TORS'], df['Scaled S2 XMS-CASPT2 Energy'],**scat['S1'])
    #ax.plot(df['Reactive TORS'], df['Scaled S0 XMS-CASPT2 Energy'],'o-',**scat['S1'], label='XMS-CASPT2/ANO-L-pVDZ')
    #ax.plot(df['Reactive TORS'], df['Scaled S1 XMS-CASPT2 Energy'],**scat['S1'], label='_no_legend_')
    #ax.plot(df['Reactive TORS'], df['Scaled S2 XMS-CASPT2 Energy'],**scat['S1'], label='_no_legend_')
    ax.set_xlim(-0.16, 0.16)
    ax.set_ylim(-5, 145)
    ax.set_xlabel('BLA($\mathrm{\AA}$)')
    #ax.set_xlabel('Torsion (degrees)')
    ax.set_ylabel('Relative Energy (kcal mol$^{-1}$)')
    #ax.set_yticks([])
    #ax.set_xticks([])
    #ax.title()
    #ax.scatter(df['psb-BLA'], df['S0 CASSCF Energy'],**caspt2_scat['S0'], label='S0 CASSCF')#, label='_nolegend_')
    #ax.scatter(df['psb-BLA'], df['S1 CASSCF Energy'],**caspt2_scat['S1'], label='S1 CASSCF')#, label='_nolegend_')
    #ax.scatter(df['psb-BLA'], df['S2 CASSCF Energy'],**caspt2_scat['S2'], label='S2 CASSCF')#, label='_nolegend_')
    #ax.legend(ncol=2) 
    fig.savefig(path+'/'+png_name+'.png', bbox_inches='tight', dpi=300)

# %%
#print(png_name_1)
#print(png_name_2)
#print(png_name_3)
cross_section_graphics(df_1, png_name_1)
#cross_section_graphics(df_2, png_name_2)
#cross_section_graphics(df_3, png_name_3)
#cross_section_graphics(df_4, png_name_4)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
